# %% [markdown]
# # My perfect holiday
# In this notebook I will introduce someone and her/his **holiday preferences** with a *picture* and a *link to a youtube video* of this holiday preference. <br>
# I am goint to continue by choosing a <span style="color:blue">name</span> for the person:

# %%
p_name= input("Person's Name: ")
p_preferances= input("Holiday Preferances: ")
print("Hello. My name is " + p_name + " my personal preferences are "+ p_preferances+ ".")
# Out:
# Person's Name: Ronaldo
# Holiday Preferances: Japan
# Hello. My name is Ronaldo my personal preferences are Japan.

# %%
'''Now that we now, how the person is called and what the person likes, let's have a look at him/her:'''
from IPython.display import Image
Image(filename= 'RLicaj (2).jpg')

# %%
### The Favorite place:
"This persons favorite place to visit - Japan."
from IPython.display import Image
Image(filename= 'Japan.jpg')

# %% [markdown]
# 'What activities the person likes in Japan'
# - Sushi
# - Judo
# - Karate

# %% [markdown]
# Last but not least, let's have a look at this beautiful place:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('00ZXaXIABMY', width=800, height=500)
# "https://www.youtube.com/watch?v=00ZXaXIABMY" is the source of the video
